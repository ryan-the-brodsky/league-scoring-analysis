# %%
import pandas as pd
pd.set_option("display.max_rows", 650)

# %%
def clean_position(position):
    position = str(position)
    last_two_letters = position[-2:len(position)].upper()
    if last_two_letters == "LB":
        return "LB"
    elif last_two_letters in ["SS", "CB", "FS", "DB"]:
        return "DB"
    elif last_two_letters in ["DE", "DT", "NT"]:
        return "DL"
    elif last_two_letters == "AN":
        return None
    else:
        return last_two_letters

# %%
def_players_2021 = pd.read_csv('./2021-defensive-player-stats.csv')
def_players_2021['return_yards'] = def_players_2021['Yds'] + def_players_2021['Yds.1']
def_players_2021['tds'] = def_players_2021['TD'] + def_players_2021['TD.1']
def_players_2021.drop(['Yds', 'TD', 'Yds.1', 'TD.1', 'Age', 'Rk'], axis='columns', inplace=True)
def_players_2021['Sfty'].fillna(0, inplace=True)
def_players_2021['Player'] = def_players_2021['Player'].apply(lambda x : x.split('\\')[0])
def_players_2021['Pos'] = def_players_2021['Pos'].astype(str)    
def_players_2021['Pos'] = def_players_2021['Pos'].apply(clean_position)
def_players_2021 = def_players_2021[def_players_2021['Pos'] != "nan"]
def_players_2021.head()
# Out:
#                 Player   Tm Pos   G  GS  Int   Lng   PD   FF  Fmb   FR   Sk  \
# 0        Jordyn Brooks  SEA  LB  17  17  0.0   0.0  5.0  0.0  0.0  1.0  1.0
# 1          C.J. Mosley  NYJ  LB  16  16  0.0   0.0  2.0  2.0  0.0  0.0  2.0
# 2  De'Vondre Campbell+  GNB  LB  16  16  2.0  13.0  5.0  2.0  0.0  1.0  2.0
# 3     Foyesade Oluokun  ATL  LB  17  17  3.0  56.0  6.0  1.0  0.0  0.0  2.0
# 4     Denzel Perryman*  LVR  LB  15  15  0.0   0.0  3.0  1.0  0.0  2.0  0.0
#
#     Comb   Solo   Ast   TFL  QBHits  Sfty  return_yards  tds
# 0  184.0  109.0  75.0  10.0     3.0   0.0           5.0  0.0
# 1  168.0  103.0  65.0   2.0     3.0   0.0           0.0  0.0
# 2  146.0  102.0  44.0   6.0     6.0   0.0          18.0  0.0
# 3  192.0  102.0  90.0   4.0     7.0   0.0          80.0  0.0
# 4  154.0  102.0  52.0   5.0     3.0   0.0           1.0  0.0

# %%
def_players_2021 = pd.read_csv('./2021-defensive-player-stats.csv')
def_players_2021['return_yards'] = def_players_2021['Yds'] + def_players_2021['Yds.1']
def_players_2021['tds'] = def_players_2021['TD'] + def_players_2021['TD.1']
def_players_2021.drop(['Yds', 'TD', 'Yds.1', 'TD.1', 'Age', 'Rk'], axis='columns', inplace=True)
def_players_2021['Sfty'].fillna(0, inplace=True)
def_players_2021['Player'] = def_players_2021['Player'].apply(lambda x : x.split('\\')[0])
def_players_2021['Pos'] = def_players_2021['Pos'].astype(str)    
def_players_2021['Pos'] = def_players_2021['Pos'].apply(clean_position)
def_players_2021 = def_players_2021[def_players_2021['Pos'] != "nan"]
def_players_2021['Season'] = "2021"

# %%
def_players_2020 = pd.read_csv('./2020-defensive-player-stats.csv')
def_players_2020['return_yards'] = def_players_2020['Yds'] + def_players_2020['Yds.1']
def_players_2020['tds'] = def_players_2020['TD'] + def_players_2020['TD.1']
def_players_2020.drop(['Yds', 'TD', 'Yds.1', 'TD.1', 'Age', 'Rk'], axis='columns', inplace=True)
def_players_2020['Sfty'].fillna(0, inplace=True)
def_players_2020['Player'] = def_players_2020['Player'].apply(lambda x : x.split('\\')[0])
def_players_2020['Pos'] = def_players_2020['Pos'].astype(str)    
def_players_2020['Pos'] = def_players_2020['Pos'].apply(clean_position)
def_players_2020 = def_players_2020[def_players_2020['Pos'] != "nan"]
def_players_2020['Season'] = "2020"

# %%
def_players_2019 = pd.read_csv('./2019-defensive-player-stats.csv')
def_players_2019['return_yards'] = def_players_2019['Yds'] + def_players_2019['Yds.1']
def_players_2019['tds'] = def_players_2019['TD'] + def_players_2019['TD.1']
def_players_2019.drop(['Yds', 'TD', 'Yds.1', 'TD.1', 'Age', 'Rk'], axis='columns', inplace=True)
def_players_2019['Sfty'].fillna(0, inplace=True)
def_players_2019['Player'] = def_players_2019['Player'].apply(lambda x : x.split('\\')[0])
def_players_2019['Pos'] = def_players_2019['Pos'].astype(str)    
def_players_2019['Pos'] = def_players_2019['Pos'].apply(clean_position)
def_players_2019 = def_players_2019[def_players_2019['Pos'] != "nan"]
def_players_2019['Season'] = "2019"

# %%
all_defensive_players = pd.concat([def_players_2019, def_players_2020, def_players_2021])
all_defensive_players.fillna(0, inplace=True)
all_defensive_players.head()
# DEF stats are Solo, Ast, TFL, PD, Int, Sk, FF, FR, return_yards, tds,
# Out:
#             Player   Tm Pos   G  GS  Int   Lng   PD   FF  Fmb  ...   Sk  \
# 0     Budda Baker*  ARI  DB  16  16  0.0   0.0  6.0  1.0  0.0  ...  0.5
# 1  Zach Cunningham  HOU  LB  16  16  0.0   0.0  2.0  0.0  0.0  ...  2.0
# 2   Blake Martinez  GNB  LB  16  16  1.0  22.0  2.0  1.0  0.0  ...  3.0
# 3        Eric Reid  CAR  DB  16  16  0.0   0.0  6.0  1.0  0.0  ...  4.0
# 4     Jordan Hicks  ARI  LB  16  16  3.0  48.0  6.0  2.0  0.0  ...  1.5
#
#     Comb   Solo   Ast   TFL  QBHits  Sfty  return_yards  tds  Season
# 0  147.0  104.0  43.0   7.0     2.0   0.0           0.0  0.0    2019
# 1  142.0   99.0  43.0   7.0     3.0   0.0          24.0  0.0    2019
# 2  155.0   97.0  58.0   5.0     3.0   0.0          22.0  0.0    2019
# 3  130.0   97.0  33.0   7.0     5.0   0.0           0.0  0.0    2019
# 4  150.0   93.0  57.0  11.0     7.0   0.0          64.0  0.0    2019
#
# [5 rows x 21 columns]

# %%
off_players_2021 = pd.read_csv('./2021-offensive-fantasy-results.csv')
off_players_2021['Player'] = off_players_2021['Player'].apply(lambda x : x.split('\\')[0])
off_players_2021['tds'] = off_players_2021['TD'] + off_players_2021['TD.1'] + off_players_2021['TD.2'] + off_players_2021['TD.3']
off_players_2021.drop(['Age', 'PosRank', 'OvRank','VBD', 'FDPt', 'Tgt', 'Att', 'Att.1', 'DKPt', 'TD', 'TD.1', 'TD.2', 'TD.3', 'Rk', 'Y/A', 'Y/R'], axis='columns', inplace=True)
off_players_2021.rename(columns={
    "Yds":"pass_yards",
    "Yds.1":"rush_yards",
    "Yds.2":"receiving_yards",
    "Int":"thrown_ints",
    "Rec":"receptions",
    "FL":"fumbles_lost"
}, inplace=True)
off_players_2021.columns.tolist()
off_players_2021.head()
# Out:
#               Player   Tm FantPos   G  GS    Cmp  pass_yards  thrown_ints  \
# 0  Jonathan Taylor*+  IND      RB  17  17    0.0         0.0          0.0
# 1      Cooper Kupp*+  LAR      WR  17  17    0.0         0.0          0.0
# 2     Deebo Samuel*+  SFO      WR  16  15    1.0        24.0          0.0
# 3         Josh Allen  BUF      QB  17  17  409.0      4407.0         15.0
# 4      Austin Ekeler  LAC      RB  16  16    0.0         0.0          0.0
#
#    rush_yards  receptions  receiving_yards  Fmb  fumbles_lost  2PM  2PP  \
# 0      1811.0        40.0            360.0  4.0           2.0  NaN  NaN
# 1        18.0       145.0           1947.0  0.0           0.0  1.0  NaN
# 2       365.0        77.0           1405.0  4.0           2.0  NaN  NaN
# 3       763.0         0.0              0.0  8.0           3.0  2.0  1.0
# 4       911.0        70.0            647.0  4.0           3.0  2.0  NaN
#
#    FantPt    PPR   tds
# 0   333.0  373.1  40.0
# 1   295.0  439.5  32.0
# 2   262.0  339.0  29.0
# 3   403.0  402.6  48.0
# 4   274.0  343.8  40.0

# %%
passing_2021 = pd.read_csv('./2021-qb-stats.csv')
passing_2021['Player'] = passing_2021['Player'].apply(lambda x : x.split('\\')[0])
passing_2021.drop(['Tm', 'Rk', 'G', 'GS', 'Age', 'QBrec','Att', 'Y/G', 'Rate', 'QBR', 'Sk', 'Sk%', 'NY/A', 'ANY/A', '4QC', 'GWD', 'Y/C', 'AY/A', 'Y/A', 'Lng', 'Yds.1', 'Int%', 'TD%', 'Cmp%'], axis='columns', inplace=True)
passing_2021.rename(columns={
    "Yds":"pass_yards",
    "Int":"thrown_ints",
    "Rec":"receptions",
    "FL":"fumbles_lost",
    "1D": "pass_first_downs", 
    "TD":"pass_touchdowns", 
    "Cmp":"pass_completions"
}, inplace=True)
passing_2021['Pos'] = passing_2021['Pos'].apply(clean_position)

rushing_2021 = pd.read_csv('./2021-rushing-stats.csv')
rushing_2021['Player'] = rushing_2021['Player'].apply(lambda x : x.split('\\')[0])
rushing_2021.drop(['Rk', 'Age', 'Y/A', 'Y/G', 'Att', 'Lng', "G", "GS", "Tm"], axis='columns', inplace=True)
rushing_2021.rename(columns={
    'Yds': 'rushing_yards',
    '1D': 'rushing_first_downs',
    'TD': 'rushing_tds',
    'Fmb':'fumbles_lost_rushing'
}, inplace=True)
rushing_2021['Pos'] = rushing_2021['Pos'].apply(clean_position)

receiving_2021 = pd.read_csv('./2021-receiving-stats.csv')
receiving_2021['Player'] = receiving_2021['Player'].apply(lambda x : x.split('\\')[0])
receiving_2021.drop(['Rk', 'Age', 'Y/R', 'R/G', 'Y/G' ,'Y/Tgt', 'Ctch%', 'Lng', 'Tm'], axis='columns', inplace=True)
receiving_2021.rename(columns={
    "Yds": "receiving_yards",
    "Rec": "receptions",
    "TD": "receiving_tds",
    "Fmb": "fumbles_lost_receiving",
    "1D": "receiving_first_downs"
    
}, inplace=True)
receiving_2021['Pos'] = receiving_2021['Pos'].apply(clean_position)


offensive_players_2021 = pd.merge(rushing_2021, passing_2021, how="outer", on='Player')
offensive_players_2021['position'] = offensive_players_2021.apply(lambda x : x['Pos_x'] if 'Pos_x' in x else x['Pos_y'], axis=1)
offensive_players_2021 = pd.merge(offensive_players_2021, receiving_2021, how="outer", on="Player")
offensive_players_2021['position'] = offensive_players_2021.apply(lambda x : x['position'] if 'position' in x else x['Pos'], axis=1)
offensive_players_2021['position'] = offensive_players_2021['position'].apply(lambda x : str(x).upper())
offensive_players_2021.drop(['Pos', 'Pos_x', 'Pos_y'], axis='columns', inplace=True)
offensive_players_2021.fillna(0, inplace=True)
offensive_players_2021['Season'] = '2021'

# %%
passing_2020 = pd.read_csv('./2020-qb-stats.csv')
passing_2020['Player'] = passing_2020['Player'].apply(lambda x : x.split('\\')[0])
passing_2020.drop(['Tm', 'Rk', 'G', 'GS', 'Age', 'QBrec','Att', 'Y/G', 'Rate', 'QBR', 'Sk', 'Sk%', 'NY/A', 'ANY/A', '4QC', 'GWD', 'Y/C', 'AY/A', 'Y/A', 'Lng', 'Yds.1', 'Int%', 'TD%', 'Cmp%'], axis='columns', inplace=True)
passing_2020.rename(columns={
    "Yds":"pass_yards",
    "Int":"thrown_ints",
    "Rec":"receptions",
    "FL":"fumbles_lost",
    "1D": "pass_first_downs", 
    "TD":"pass_touchdowns", 
    "Cmp":"pass_completions"
}, inplace=True)
passing_2020['Pos'] = passing_2020['Pos'].apply(clean_position)

rushing_2020 = pd.read_csv('./2020-rushing-stats.csv')
rushing_2020['Player'] = rushing_2020['Player'].apply(lambda x : x.split('\\')[0])
rushing_2020.drop(['Rk', 'Age', 'Y/A', 'Y/G', 'Att', 'Lng', "G", "GS", "Tm"], axis='columns', inplace=True)
rushing_2020.rename(columns={
    'Yds': 'rushing_yards',
    '1D': 'rushing_first_downs',
    'TD': 'rushing_tds',
    'Fmb':'fumbles_lost_rushing'
}, inplace=True)
rushing_2020['Pos'] = rushing_2020['Pos'].apply(clean_position)

receiving_2020 = pd.read_csv('./2020-receiving-stats.csv')
receiving_2020['Player'] = receiving_2020['Player'].apply(lambda x : x.split('\\')[0])
receiving_2020.drop(['Rk', 'Age', 'Y/R', 'R/G', 'Y/G' ,'Y/Tgt', 'Ctch%', 'Lng', 'Tm'], axis='columns', inplace=True)
receiving_2020.rename(columns={
    "Yds": "receiving_yards",
    "Rec": "receptions",
    "TD": "receiving_tds",
    "Fmb": "fumbles_lost_receiving",
    "1D": "receiving_first_downs"
    
}, inplace=True)
receiving_2020['Pos'] = receiving_2020['Pos'].apply(clean_position)


offensive_players_2020 = pd.merge(rushing_2020, passing_2020, how="outer", on='Player')
offensive_players_2020['position'] = offensive_players_2020.apply(lambda x : x['Pos_x'] if 'Pos_x' in x else x['Pos_y'], axis=1)
offensive_players_2020 = pd.merge(offensive_players_2020, receiving_2020, how="outer", on="Player")
offensive_players_2020['position'] = offensive_players_2020.apply(lambda x : x['position'] if 'position' in x else x['Pos'], axis=1)
offensive_players_2020['position'] = offensive_players_2020['position'].apply(lambda x : str(x).upper())
offensive_players_2020.drop(['Pos', 'Pos_x', 'Pos_y'], axis='columns', inplace=True)
offensive_players_2020.fillna(0, inplace=True)
offensive_players_2020['Season'] = '2020'

# %%
passing_2019 = pd.read_csv('./2019-qb-stats.csv')
passing_2019['Player'] = passing_2019['Player'].apply(lambda x : x.split('\\')[0])
passing_2019.drop(['Tm', 'Rk', 'G', 'GS', 'Age', 'QBrec','Att', 'Y/G', 'Rate', 'QBR', 'Sk', 'Sk%', 'NY/A', 'ANY/A', '4QC', 'GWD', 'Y/C', 'AY/A', 'Y/A', 'Lng', 'Yds.1', 'Int%', 'TD%', 'Cmp%'], axis='columns', inplace=True)
passing_2019.rename(columns={
    "Yds":"pass_yards",
    "Int":"thrown_ints",
    "Rec":"receptions",
    "FL":"fumbles_lost",
    "1D": "pass_first_downs", 
    "TD":"pass_touchdowns", 
    "Cmp":"pass_completions"
}, inplace=True)
passing_2019['Pos'] = passing_2019['Pos'].apply(clean_position)

rushing_2019 = pd.read_csv('./2019-rushing-stats.csv')
rushing_2019['Player'] = rushing_2019['Player'].apply(lambda x : x.split('\\')[0])
rushing_2019.drop(['Rk', 'Age', 'Y/A', 'Y/G', 'Att', 'Lng', "G", "GS", "Tm"], axis='columns', inplace=True)
rushing_2019.rename(columns={
    'Yds': 'rushing_yards',
    '1D': 'rushing_first_downs',
    'TD': 'rushing_tds',
    'Fmb':'fumbles_lost_rushing'
}, inplace=True)
rushing_2019['Pos'] = rushing_2019['Pos'].apply(clean_position)

receiving_2019 = pd.read_csv('./2019-receiving-stats.csv')
receiving_2019['Player'] = receiving_2019['Player'].apply(lambda x : x.split('\\')[0])
receiving_2019.drop(['Rk', 'Age', 'Y/R', 'R/G', 'Y/G' ,'Y/Tgt', 'Ctch%', 'Lng', 'Tm'], axis='columns', inplace=True)
receiving_2019.rename(columns={
    "Yds": "receiving_yards",
    "Rec": "receptions",
    "TD": "receiving_tds",
    "Fmb": "fumbles_lost_receiving",
    "1D": "receiving_first_downs"
    
}, inplace=True)
receiving_2019['Pos'] = receiving_2019['Pos'].apply(clean_position)


offensive_players_2019 = pd.merge(rushing_2019, passing_2019, how="outer", on='Player')
offensive_players_2019['position'] = offensive_players_2019.apply(lambda x : x['Pos_x'] if 'Pos_x' in x else x['Pos_y'], axis=1)
offensive_players_2019 = pd.merge(offensive_players_2019, receiving_2019, how="outer", on="Player")
offensive_players_2019['position'] = offensive_players_2019.apply(lambda x : x['position'] if 'position' in x else x['Pos'], axis=1)
offensive_players_2019['position'] = offensive_players_2019['position'].apply(lambda x : str(x).upper())
offensive_players_2019.drop(['Pos', 'Pos_x', 'Pos_y'], axis='columns', inplace=True)
offensive_players_2019.fillna(0, inplace=True)
offensive_players_2019['Season'] = '2019'

# %%
all_offensive_players = pd.concat([offensive_players_2019, offensive_players_2020, offensive_players_2021])

def pull_position_from_fantasy_results(player):
    if player['position'] in ["NAN", "NONE"]:
        return off_players_2021[off_players_2021['player'] == player]
    
all_offensive_players['position'] = all_offensive_players.apply(pull_position_from_fantasy_results)
# Out:
#     position                    Player
# 0         RB           Derrick Henry *
# 1         RB          Ezekiel Elliott*
# 2         RB               Nick Chubb*
# 3         RB     Christian McCaffrey*+
# 4         RB              Chris Carson
# 5         RB                 Joe Mixon
# 6         RB         Leonard Fournette
# 7         RB              Dalvin Cook*
# 8         RB               Marlon Mack
# 9         RB               Sony Michel
# 10        RB              Le'Veon Bell
# 11        RB               Carlos Hyde
# 12        RB               Josh Jacobs
# 13        RB          David Montgomery
# 14        RB               Aaron Jones
# 15        RB           Phillip Lindsay
# 16        RB               Todd Gurley
# 17        RB            Saquon Barkley
# 18        RB           Adrian Peterson
# 19        RB              Mark Ingram*
# 20        RB           Devonta Freeman
# 21        RB             Miles Sanders
# 22        QB           Lamar Jackson*+
# 23        RB           Ronald Jones II
# 24        RB             Alvin Kamara*
# 25      NONE              Kenyan Drake
# 26        RB                Frank Gore
# 27        RB             Melvin Gordon
# 28        RB             Peyton Barber
# 29        RB          Devin Singletary
# 30        RB           Latavius Murray
# 31        RB             Tevin Coleman
# 32      NONE            Raheem Mostert
# 33      NONE               Gus Edwards
# 34        RB             Austin Ekeler
# 35      NONE             Royce Freeman
# 36        RB               Matt Breida
# 37        RB             Jordan Howard
# 38        RB              James Conner
# 39        RB           Kerryon Johnson
# 40        RB           Damien Williams
# 41        QB                Josh Allen
# 42      NONE           Benny Snell Jr.
# 43      NONE        DeAndre Washington
# 44      NONE           Jamaal Williams
# 45        RB              LeSean McCoy
# 46      NONE        Alexander Mattison
# 47        RB             David Johnson
# 48        QB              Kyler Murray
# 49        RB             Bo Scarbrough
# 50      NONE              Tony Pollard
# 51      NONE              Duke Johnson
# 52        QB           Deshaun Watson*
# 53      NONE                Brian Hill
# 54        QB           Russell Wilson*
# 55        RB             Kalen Ballage
# 56      NONE             Malcolm Brown
# 57        QB        Gardner Minshew II
# 58      NONE               James White
# 59      NONE            Jaylen Samuels
# 60      NONE              Rex Burkhead
# 61      NONE             Rashaad Penny
# 62        RB               Tarik Cohen
# 63      NONE                Ty Johnson
# 64      NONE             Patrick Laird
# 65        QB              Carson Wentz
# 66      NONE              Boston Scott
# 67      NONE             Chase Edmonds
# 68        RB              Bilal Powell
# 69        QB            Jameis Winston
# 70      NONE              Justice Hill
# 71        QB           Jacoby Brissett
# 72        QB          Ryan Fitzpatrick
# 73        RB                Dion Lewis
# 74      NONE           Giovani Bernard
# 75      NONE               Mark Walton
# 76      NONE              Nyheim Hines
# 77        QB              Dak Prescott
# 78      NONE            Jordan Wilkins
# 79      NONE                Mike Boone
# 80      NONE         Jonathan Williams
# 81        QB         Mitchell Trubisky
# 82        QB           Jimmy Garoppolo
# 83        QB            Aaron Rodgers*
# 84        QB              Daniel Jones
# 85      NONE               Kareem Hunt
# 86        QB          Patrick Mahomes*
# 87        QB           Ryan Tannehill*
# 88      NONE             Derrius Guice
# 89      NONE           Darrel Williams
# 90      NONE         Darrell Henderson
# 91      NONE             Jalen Richard
# 92        RB             J.D. McKissic
# 93      NONE            Chris Thompson
# 94      NONE           Darwin Thompson
# 95      NONE              Myles Gaskin
# 96      NONE          Ryquell Armstead
# 97        QB                 Matt Ryan
# 98        QB               Sam Darnold
# 99        QB                Jared Goff
# 100       QB                Kyle Allen
# 101       QB               Andy Dalton
# 102       RB             Ty Montgomery
# 103       QB             Kirk Cousins*
# 104     NONE              Jon Hilliman
# 105     NONE             Wayne Gallman
# 106     NONE            Justin Jackson
# 107       QB         Teddy Bridgewater
# 108       QB            Baker Mayfield
# 109       QB                Derek Carr
# 110       WR               Taysom Hill
# 111     NONE               Jeff Wilson
# 112       QB                 Tom Brady
# 113       QB            Marcus Mariota
# 114     NONE          Kerrith Whyte Jr
# 115     NONE            Ameer Abdullah
# 116     NONE              C.J. Prosise
# 117       QB              Jeff Driskel
# 118     NONE              Trey Edmunds
# 119     NONE            Qadree Ollison
# 120     NONE         Wendell Smallwood
# 121     NONE                 Ito Smith
# 122       QB             Devlin Hodges
# 123       QB             Mason Rudolph
# 124     NONE        Robert Griffin III
# 125       QB            Dwayne Haskins
# 126       QB          Matthew Stafford
# 127       WR             Curtis Samuel
# 128     NONE                Tra Carson
# 129     NONE              Travis Homer
# 130       QB                 Drew Lock
# 131     NONE   Cordarrelle Patterson*+
# 132       RB            Darren Sproles
# 133     NONE              Spencer Ware
# 134       WR              Robert Woods
# 135     NONE               T.J. Yeldon
# 136     NONE             C.J. Anderson
# 137     NONE           Reggie Bonnafon
# 138     NONE            Brandon Bolden
# 139     NONE             Elijhaa Penny
# 140       WR              Deebo Samuel
# 141     NONE                Mike Davis
# 142     NONE         Dontrell Hilliard
# 143       QB                Joe Flacco
# 144     NONE            Marshawn Lynch
# 145     NONE              Paul Perkins
# 146       QB             Philip Rivers
# 147     NONE             Dalyn Dawkins
# 148     NONE           Dare Ogunbowale
# 149     NONE                 Jay Ajayi
# 150     NONE             Brandon Allen
# 151     NONE            Javorius Allen
# 152     NONE               Ryan Finley
# 153     NONE                 Wes Hills
# 154     NONE               Alec Ingold
# 155       WR            Christian Kirk
# 156     NONE            Troymaine Pope
# 157     NONE              Tyrod Taylor
# 158       QB               Drew Brees*
# 159     NONE              Taiwan Jones
# 160       QB               Case Keenum
# 161     NONE             Devine Ozigbo
# 162     NONE               Steven Sims
# 163     NONE                Josh Adams
# 164       QB              David Blough
# 165     NONE         Tony Brooks-James
# 166       WR            Julian Edelman
# 167       WR              Tyreek Hill*
# 168       QB               Brian Hoyer
# 169       WR           Isaiah McKenzie
# 170     NONE         Dwayne Washington
# 171     NONE                Will Grier
# 172       FB                 C.J. Ham*
# 173     NONE             Brett Hundley
# 174       FB                 Zach Line
# 175       FB                Derek Watt
# 176     NONE                Alex Armah
# 177     NONE              Tavon Austin
# 178       WR             Brandin Cooks
# 179       QB              Chase Daniel
# 180     NONE              Sean Mannion
# 181       WR                D.J. Moore
# 182       WR          Sterling Shepard
# 183     NONE                 Tim Boyle
# 184       WR              Stefon Diggs
# 185       WR             Alex Erickson
# 186       WR              N'Keal Harry
# 187     NONE              Buddy Howell
# 188       TE           George Kittle*+
# 189     NONE             A.J. McCarron
# 190     NONE                Matt Moore
# 191     NONE                Cam Newton
# 192     NONE             Samaje Perine
# 193     NONE             Josh Reynolds
# 194       FB               Keith Smith
# 195       WR            Dede Westbrook
# 196     NONE           Dexter Williams
# 197     NONE             Albert Wilson
# 198     NONE             Kenjon Barner
# 199       WR                Tyler Boyd
# 200     NONE           Parris Campbell
# 201     NONE              Trevor Davis
# 202       QB                Nick Foles
# 203     NONE              Russell Gage
# 204     NONE              Jakeem Grant
# 205     NONE              Ryan Griffin
# 206       WR           Mecole Hardman*
# 207     NONE             Damien Harris
# 208     NONE           Deonte Harris*+
# 209     NONE             Andy Isabella
# 210     NONE          D'Ernest Johnson
# 211       WR           Diontae Johnson
# 212       WR             Tyler Lockett
# 213       QB               Eli Manning
# 214     NONE           Jordan Scarlett
# 215     NONE           Anthony Sherman
# 216       TE               Jonnu Smith
# 217       WR              Adam Thielen
# 218     NONE           De'Lance Turner
# 219       WR             Keenan Allen*
# 220       WR         Odell Beckham Jr.
# 221       WR                A.J. Brown
# 222       WR              Randall Cobb
# 223       FB           Patrick DiMarco
# 224       WR           Phillip Dorsett
# 225       TE               Evan Engram
# 226       TE                 Noah Fant
# 227     NONE             Josh Ferguson
# 228       WR            Taylor Gabriel
# 229     NONE           Garrett Gilbert
# 230       WR              Ted Ginn Jr.
# 231       FB            Kyle Juszczyk*
# 232     NONE                John Kelly
# 233     NONE                T.J. Logan
# 234     NONE               David Moore
# 235     NONE              Nick Mullens
# 236     NONE            Senorise Perry
# 237     NONE                Josh Rosen
# 238       WR                 John Ross
# 239     NONE              Mohamed Sanu
# 240     NONE               Matt Schaub
# 241     NONE             Vyncint Smith
# 242     NONE           Diontae Spencer
# 243       WR         Courtland Sutton*
# 244     NONE               Zach Zenner
# 245       WR            Nelson Agholor
# 246     NONE              Matt Barkley
# 247     NONE              Jordan Berry
# 248     NONE           Devontae Booker
# 249     NONE             Blake Bortles
# 250       WR                John Brown
# 251       WR                 DJ Chark*
# 252     NONE               Keke Coutee
# 253     NONE             James Develin
# 254     NONE             Robert Foster
# 255     NONE              Mike Glennon
# 256       WR         DeAndre Hopkins*+
# 257     NONE              Richie James
# 258       WR              Julio Jones*
# 259       WR              Marvin Jones
# 260       WR               Cooper Kupp
# 261     NONE            Anthony Levine
# 262     NONE               Josh McCown
# 263       QB                Colt McCoy
# 264       WR              D.K. Metcalf
# 265     NONE              Scott Miller
# 266     NONE                 Ryan Nall
# 267       WR               Zach Pascal
# 268       WR          Breshad Perriman
# 269       WR             Calvin Ridley
# 270       WR              Willie Snead
# 271     NONE           Jarrett Stidham
# 272     NONE         De'Anthony Thomas
# 273       WR  Marquez Valdes-Scantling
# 274       TE             Darren Waller
# 275       WR             Sammy Watkins
# 276     NONE               Jamal Agnew
# 277       WR          Geronimo Allison
# 278       WR            Robby Anderson
# 279     NONE               Bryan Anger
# 280       TE               Andrew Beck
# 281     NONE             Antonio Brown
# 282     NONE             Derek Carrier
# 283     NONE               Keelan Cole
# 284       WR             Amari Cooper*
# 285     NONE             Pharoh Cooper
# 286       WR           Jamison Crowder
# 287       TE               Will Dissly
# 288     NONE               Tyler Ervin
# 289     NONE            Gerald Everett
# 290     NONE               Isaiah Ford
# 291     NONE             Bennie Fowler
# 292     NONE             John Franklin
# 293       WR             Chris Godwin*
# 294       WR          Marquise Goodwin
# 295     NONE               Josh Gordon
# 296     NONE                Matt Haack
# 297     NONE               Marvin Hall
# 298       DB               Erik Harris
# 299       WR             Johnny Holton
# 300     NONE            Adam Humphries
# 301       FB             Andy Janovich
# 302       WR            Alshon Jeffery
# 303     NONE           KeeSean Johnson
# 304     NONE           Olabisi Johnson
# 305     NONE               Colin Jones
# 306     NONE                 Zay Jones
# 307       TE             Travis Kelce*
# 308     NONE              Brett Kern*+
# 309       TE               Dawson Knox
# 310       WR            Jarvis Landry*
# 311     NONE              Allen Lazard
# 312     NONE               Marqise Lee
# 313       TE            Vance McDonald
# 314     NONE            Trace McSorley
# 315       WR            Anthony Miller
# 316     NONE               Chris Moore
# 317     NONE             Alfred Morris
# 318       LG          Quenton Nelson*+
# 319     NONE             Kalif Raymond
# 320       WR           Paul Richardson
# 321     NONE            Andre Roberts*
# 322       WR            Allen Robinson
# 323     NONE        Ben Roethlisberger
# 324       WR            Chester Rogers
# 325     NONE             Da'Mari Scott
# 326     NONE                Nick Scott
# 327       WR               Golden Tate
# 328       WR          Michael Thomas*+
# 329     NONE              Danny Vitale
# 330     NONE                 Greg Ward
# 331     NONE              Trevon Wesco
# 332       WR             Mike Williams
# 333       WR             Jarius Wright
# 334      NAN                 Luke Falk
# 335      NAN          Emmanuel Sanders
# 336      NAN             Johnny Hekker
# 337      NAN                  Andy Lee
# 338      NAN            Danny Amendola
# 339      NAN               Logan Cooke
# 340      NAN              Dante Pettis
# 341      NAN           Michael Palardy
# 342      NAN             Kelvin Harmon
# 343      NAN            Trevor Siemian
# 344      NAN               Alex Tanney
# 345      NAN           Dustin Colquitt
# 346      NAN              Jake Elliott
# 347      NAN                  Sam Koch
# 348      NAN                Zach Ertz*
# 349      NAN            Davante Adams*
# 350      NAN          Larry Fitzgerald
# 351      NAN            Austin Hooper*
# 352      NAN            DeVante Parker
# 353      NAN              Tyler Higbee
# 354      NAN              Cole Beasley
# 355      NAN               Mike Evans*
# 356      NAN            Michael Gallup
# 357      NAN           Kenny Golladay*
# 358      NAN             Mark Andrews*
# 359      NAN              Jason Witten
# 360      NAN            Dallas Goedert
# 361      NAN            Terry McLaurin
# 362      NAN              Hunter Henry
# 363      NAN                Greg Olsen
# 364      NAN              Mike Gesicki
# 365      NAN               Will Fuller
# 366      NAN            Hunter Renfrow
# 367      NAN            Darius Slayton
# 368      NAN              Chris Conley
# 369      NAN            Marquise Brown
# 370      NAN               T.Y. Hilton
# 371      NAN          James Washington
# 372      NAN               Jared Cook*
# 373      NAN               Corey Davis
# 374      NAN               Jack Doyle*
# 375      NAN              Tyler Eifert
# 376      NAN       JuJu Smith-Schuster
# 377      NAN           Tyrell Williams
# 378      NAN           Jacob Hollister
# 379      NAN              Kenny Stills
# 380      NAN                Auden Tate
# 381      NAN              Kyle Rudolph
# 382      NAN              Jimmy Graham
# 383      NAN              Jordan Akins
# 384      NAN             Cameron Brate
# 385      NAN             Irv Smith Jr.
# 386      NAN          Demaryius Thomas
# 387      NAN              Darren Fells
# 388      NAN               O.J. Howard
# 389      NAN              Damiere Byrd
# 390      NAN            T.J. Hockenson
# 391      NAN               Allen Hurns
# 392      NAN         Demarcus Robinson
# 393      NAN          Preston Williams
# 394      NAN                Nick Boyle
# 395      NAN                Eric Ebron
# 396      NAN              Blake Jarwin
# 397      NAN               Kaden Smith
# 398      NAN           Kendrick Bourne
# 399      NAN              Hayden Hurst
# 400      NAN          DaeSean Hamilton
# 401      NAN               C.J. Uzomah
# 402      NAN             Jakobi Meyers
# 403      NAN                Trey Quinn
# 404      NAN           Jeremy Sprinkle
# 405      NAN                 Josh Hill
# 406      NAN              Tajae Sharpe
# 407      NAN              Cody Latimer
# 408      NAN             Foster Moreau
# 409      NAN              Seth Roberts
# 410      NAN            Delanie Walker
# 411      NAN              Justin Hardy
# 412      NAN              Charles Clay
# 413      NAN             Rhett Ellison
# 414      NAN            Tre'Quan Smith
# 415      NAN                Javon Wims
# 416      NAN            Marcus Johnson
# 417      NAN              Nick Vannett
# 418      NAN                Ben Watson
# 419      NAN               Jaron Brown
# 420      NAN               Jesse James
# 421      NAN               Tim Patrick
# 422      NAN                Ian Thomas
# 423      NAN              Logan Thomas
# 424      NAN              Ross Dwelley
# 425      NAN          Demetrius Harris
# 426      NAN            Marcedes Lewis
# 427      NAN              Malik Turner
# 428      NAN             Justin Watson
# 429      NAN             Maxx Williams
# 430      NAN               Trey Burton
# 431      NAN           Anthony Firkser
# 432      NAN             Jeff Heuerman
# 433      NAN       James O'Shaughnessy
# 434      NAN         Ricky Seals-Jones
# 435      NAN              Miles Boykin
# 436      NAN              Matt LaCosse
# 437      NAN              Nick O'Leary
# 438      NAN               Geoff Swaim
# 439      NAN              Seth Devalve
# 440      NAN           Dontrelle Inman
# 441      NAN              Jake Kumerow
# 442      NAN             Byron Pringle
# 443      NAN             Damion Ratley
# 444      NAN             Duke Williams
# 445      NAN           Christian Blake
# 446      NAN            DeAndre Carter
# 447      NAN               Keelan Doss
# 448      NAN       JJ Arcega-Whiteside
# 449      NAN              Vernon Davis
# 450      NAN              Mack Hollins
# 451      NAN             Robert Tonyan
# 452      NAN                 Deon Cain
# 453      NAN             Jaeden Graham
# 454      NAN              Virgil Green
# 455      NAN            DeSean Jackson
# 456      NAN            Joshua Perkins
# 457      NAN              Adam Shaheen
# 458      NAN          Laquon Treadwell
# 459      NAN             Damion Willis
# 460      NAN               Mo Alie-Cox
# 461      NAN                Dan Arnold
# 462      NAN                Blake Bell
# 463      NAN          Antonio Callaway
# 464      NAN             Tyler Conklin
# 465      NAN              Hale Hentges
# 466      NAN               Chris Hogan
# 467      NAN            Jesper Horsted
# 468      NAN           Patrick Ricard*
# 469      NAN              Luke Stocker
# 470      NAN             Tommy Sweeney
# 471      NAN              Ryan Switzer
# 472      NAN              Luke Willson
# 473      NAN           Brandon Zylstra
# 474      NAN              Daniel Brown
# 475      NAN                J.P. Holtz
# 476      NAN             Durham Smythe
# 477      NAN           Travis Benjamin
# 478      NAN           Braxton Berrios
# 479      NAN            Ben Braunecker
# 480      NAN            Troy Fumagalli
# 481      NAN                 Ryan Izzo
# 482      NAN               Tyler Kroft
# 483      NAN              Andre Patton
# 484      NAN             MyCole Pruitt
# 485      NAN              Riley Ridley
# 486      NAN            Marcell Ateman
# 487      NAN           Stephen Carlson
# 488      NAN               David Njoku
# 489      NAN               Drew Sample
# 490      NAN               Devin Smith
# 491      NAN        Cedrick Wilson Jr.
# 492      NAN               Nick Bawden
# 493      NAN          Khari Blasingame
# 494      NAN          Michael Crabtree
# 495      NAN                Ryan Grant
# 496      NAN           Rashard Higgins
# 497      NAN            KhaDarel Hodge
# 498      NAN               Tevin Jones
# 499      NAN           Jordan Matthews
# 500      NAN            Donte Moncrief
# 501      NAN              Johnny Mundt
# 502      NAN                 JJ Nelson
# 503      NAN           Trent Sherfield
# 504      NAN                 Lee Smith
# 505      NAN               Ross Travis
# 506      NAN             Clive Walford
# 507      NAN            DeAndrew White
# 508      NAN                 Cody Core
# 509      NAN              Geremy Davis
# 510      NAN            Devin Funchess
# 511      NAN                T.J. Jones
# 512      NAN           Lance Kendricks
# 513      NAN                Chris Lacy
# 514      NAN        Stanley Morgan Jr.
# 515      NAN               Josh Oliver
# 516      NAN           Russell Shepard
# 517      NAN               Bobo Wilson
# 518      NAN               Deon Yelder
# 519      NAN         Olamide Zaccheaus
# 520      NAN                Chad Beebe
# 521      NAN              Josh Bellamy
# 522      NAN              Nick Bellore
# 523      NAN                C.J. Board
# 524      NAN                Fred Brown
# 525      NAN             Pharaoh Brown
# 526      NAN           Deontay Burnett
# 527      NAN             Cethan Carter
# 528      NAN              Robert Davis
# 529      NAN              Ashton Dulin
# 530      NAN              Rico Gafford
# 531      NAN         Alexander Hollins
# 532      NAN            Cody Hollister
# 533      NAN             Tanner Hudson
# 534      NAN             Ishmael Hyman
# 535      NAN           Darius Jennings
# 536      NAN           Steven Mitchell
# 537      NAN               Jason Moore
# 538      NAN               Isaac Nauta
# 539      NAN             Roosevelt Nix
# 540      NAN          Gunner Olszewski
# 541      NAN              Eric Saubert
# 542      NAN            Scott Simonson
# 543      NAN                  Cam Sims
# 544      NAN               Mike Thomas
# 545      NAN            Levine Toilolo
# 546      NAN            Michael Walker
# 547      NAN            Antony Auclair
# 548      NAN          Garrett Bradbury
# 549      NAN            Ventell Bryant
# 550      NAN               Kevin Byard
# 551      NAN               Austin Carr
# 552      NAN               Sean Culkin
# 553      NAN           Darrell Daniels
# 554      NAN                Cody Davis
# 555      NAN             Rashard Davis
# 556      NAN              Dion Dawkins
# 557      NAN            Michael Deiter
# 558      NAN             Quincy Enunwa
# 559      NAN               Zach Gentry
# 560      NAN             Cyril Grayson
# 561      NAN            Xavier Grimble
# 562      NAN             Dwayne Harris
# 563      NAN             Chris Herndon
# 564      NAN            Krishawn Hogan
# 565      NAN             Jakob Johnson
# 566      NAN             Charles Jones
# 567      NAN              Dennis Kelly
# 568      NAN                Ben Koyack
# 569      NAN            Chris Manhertz
# 570      NAN             Codey McElroy
# 571      NAN              Kaleb McGary
# 572      NAN               Ricky Ortiz
# 573      NAN        David Quessenberry
# 574      NAN           Elandon Roberts
# 575      NAN              Ty Sambrailo
# 576      NAN             Jason Sanders
# 577      NAN            Dalton Schultz
# 578      NAN              Jaleel Scott
# 579      NAN          Darrius Shepherd
# 580      NAN                Jeff Smith
# 581      NAN            Tyrone Swoopes
# 582      NAN              Wyatt Teller
# 583      NAN             Jordan Thomas
# 584      NAN            Eric Tomlinson
# 585      NAN                John Ursua
# 586      NAN                  Vita Vea
# 587      NAN         Christian Wilkins
# 0         RB          Derrick Henry *+
# 1         RB              Dalvin Cook*
# 2         RB              Josh Jacobs*
# 3         RB          David Montgomery
# 4         RB           Ezekiel Elliott
# 5         RB            James Robinson
# 6         RB              Kenyan Drake
# 7         RB           Jonathan Taylor
# 8         RB             Melvin Gordon
# 9         RB              Aaron Jones*
# 10        RB               Kareem Hunt
# 11        RB               Todd Gurley
# 12        RB           Ronald Jones II
# 13        RB               Nick Chubb*
# 14        RB                Frank Gore
# 15        RB             Alvin Kamara*
# 16        RB     Clyde Edwards-Helaire
# 17        RB            Antonio Gibson
# 18        RB              James Conner
# 19        RB                Mike Davis
# 20        RB             Miles Sanders
# 21        QB             Lamar Jackson
# 22        RB           Adrian Peterson
# 23        RB          Devin Singletary
# 24        RB             Wayne Gallman
# 25        RB             David Johnson
# 26        RB           Latavius Murray
# 27      NONE                 Cam Akers
# 28        RB               Gus Edwards
# 29        RB              Myles Gaskin
# 30        RB              Chris Carson
# 31        RB         Darrell Henderson
# 32        RB             Damien Harris
# 33        QB                Cam Newton
# 34      NONE              J.K. Dobbins
# 35        QB             Kyler Murray*
# 36      NONE               Jeff Wilson
# 37        RB           Giovani Bernard
# 38        RB                 Joe Mixon
# 39      NONE           Jamaal Williams
# 40        RB           Phillip Lindsay
# 41        RB             Austin Ekeler
# 42      NONE             D'Andre Swift
# 43      NONE                 Zack Moss
# 44      NONE             Joshua Kelley
# 45      NONE           Benny Snell Jr.
# 46        RB            Raheem Mostert
# 47        QB               Josh Allen*
# 48      NONE             Malcolm Brown
# 49      NONE              Tony Pollard
# 50      NONE                Brian Hill
# 51      NONE             Chase Edmonds
# 52      NONE         Leonard Fournette
# 53      NONE        Alexander Mattison
# 54      NONE             Peyton Barber
# 55      NONE           Devontae Booker
# 56      NONE             Kalen Ballage
# 57        QB           Deshaun Watson*
# 58      NONE              Nyheim Hines
# 59        WR               Taysom Hill
# 60        RB             J.D. McKissic
# 61      NONE            Jordan Wilkins

# %%
scoring_system = {
    "pass_yards": .04,
    "pass_touchdowns": 4,
    "pass_completions": 0,
    "pass_first_downs": 0,
    "rushing_yards": .1,
    "rushing_first_downs": 0,
    "rushing_tds": 6,
    "rushing_fumbles_lost": -2,
    "receptions": 0,
    "receiving_yards": .1,
    "receiving_first_downs": 0,
    "receiving_tds": 6,
    "receiving_fumbles_lost": -2,
    "thrown_ints": -2,
    "receptions": 0,
    "Solo": 1,
    "TFL": 3,
    "PD": 3,
    "Int": 6,
    "Sk": 6,
    "FF": 3,
    "FR": 3,
    "return_yards": .1,
    "tds": 6
}

# %%
# At this point we have all_defensive_players and all_offensive_players comprising three seasons of stats
# map(scoring_system.keys(), lambda scoring_key : player[scoring_key] * scoring_system[scoring_key]
def tally_points_for_player(player):
    total = 0
    for scoring_key in scoring_system.keys():
        if scoring_key in player:
            total += scoring_system[scoring_key] * player[scoring_key]
    return total

all_defensive_players['fantasy_pts'] = all_defensive_players.apply(tally_points_for_player, axis=1)
all_offensive_players['fantasy_pts'] = all_offensive_players.apply(tally_points_for_player, axis=1)

# %%
rbs = all_offensive_players[all_offensive_players['position'] == "RB"]
wrs = all_offensive_players[all_offensive_players['position'] == "WR"]
tes = all_offensive_players[all_offensive_players['position'] == "TE"]
qbs = all_offensive_players[all_offensive_players['position'] == "QB"]
lbs = all_defensive_players[all_defensive_players['Pos'] == "LB"]
dbs = all_defensive_players[all_defensive_players['Pos'] == "DB"]
dls = all_defensive_players[all_defensive_players['Pos'] == "DL"]

positions = [lbs, dbs, dls, rbs, wrs, tes, qbs]
position_names = ["LB", "DB", "DL", "RB", "WR", "TE", "QB"]
ultimate_data = []
index = 0
for position in positions:
    nums = position.sort_values(by="fantasy_pts", ascending=False).head(36)["fantasy_pts"].describe().to_dict()
    nums['position'] = position_names[index]
    index += 1
    ultimate_data.append(nums)
ultimate_df = pd.DataFrame(ultimate_data)
ultimate_df.set_index("position", inplace=True)
ultimate_df.head(10)
# Out:
#           count        mean        std     min      25%     50%      75%  \
# position
# LB         36.0  189.794444  30.561058  161.20  165.225  179.70  199.625
# DB         36.0  158.983333  14.900575  139.60  148.775  157.05  167.825
# DL         36.0  160.766667  20.211991  139.10  144.750  152.55  170.825
# RB         36.0  227.548889  46.828894  179.70  192.850  211.35  251.350
# WR         36.0  180.556111  33.976975  150.42  157.050  168.40  188.200
# TE         30.0   77.022000  46.739060    9.70   45.800   67.55  103.265
# QB         36.0  332.175000  41.163404  274.36  297.475  330.17  367.025
#
#              max
# position
# LB        291.10
# DB        203.60
# DL        211.00
# RB        353.20
# WR        292.50
# TE        190.10
# QB        419.68
